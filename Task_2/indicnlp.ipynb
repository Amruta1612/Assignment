# %%
with open('faq.txt') as f:
    contents = f.read()
    print(contents)
# Out:
# What is Poshan Abhiyaan?
# Poshan Abhiyaan is Indiaâ€™s flagship programme to improve nutritional outcomes for children, adolescents, pregnant women and lactating mothers by leveraging technology, a targeted approach and convergence.
# What is the purpose of Launching Poshan Tracker?
# The purpose of POSHAN Tracker application is to provide a 360-degree view of the activities of the Anganwadi Centre (AWC), service deliveries of Anganwadi Workers (AWWs) and complete beneficiary management for pregnant women, lactating mothers and children. The proposed system should enable real-time monitoring and tracking of all AWCs, AWWs and beneficiaries on the defined indicators.
# How can one Download Poshan Tracker App?
# Poshan Tracker App is available over Google playstore https://play.google.com/store/apps/details?id=com.poshantracker
# Is poshan trackers app available over Apple I Store also?
# No, Poshan Tracker is available only for Android version
# What is the minimum requirement to install Poshan Tracker App in mobile?
# Poshan Tracker App can only be installed in Android Phone with Android version 6.0 and above.
# Can App be accessed without internet?
# App can be accessed offline, currently daily tracking feature is available for offline data entry. Offline mode can store latest 3 days data.
# Who are the target userbase of Poshan Tracker App?
# Poshan Tracker App is meant for Aanganwadi workers, Anganwadi centers to enter beneficiaries data in the forms. It is not at all developed for general public.
# How to Login in Poshan Tracker App?
# AWWs are requested to enter their mobile numbers in the Login screen. An OTP will be sent to your registered mobile number, post which you are required too set your MPIN.
# What is MPIN?
# MPIN is a 4 digits passcode which is set by an Anganwadi worker while registering over the Poshan Tracker App.
# How to set MPIN?
# MPIN can be set by respective Anganwadi worker by requesting an OTP against his/her mobile number. If Mobile number is already present in the database, the respective Anganwadi person will receive 4 digits OTP on registered mobile number. Post entering the OTP, AWW can easily set customized MPIN.
# When and how to use MPIN?
# While login to the Poshan Tracker App, AWWs are required to enter the MPIN set by them. This MPIN will act as a passcode to run the Poshan Tracker App and entering the information in the beneficiaries forms.
# How to Reset MPIN?
# MPIN can be easily reset by any AWW/AWC user. You are required to click on Forgot MPIN, and enter your registered mobile number. You will receive and OTP on your registered mobile number and you can ealily reset your MPIN
# In How many languages the Poshan Tracker App is available?
# Poshan Tracker App is available in 22 different languages
# The various languages available are:
# English
# Hindi
# Gujarati
# Punjabi
# Marathi
# Bangla
# Kannada
# Tamil
# Telugu
# Malyalam
# Odia
# Assamese
# Nepali
# Dogri
# Konkani
# Sindhi
# Bodo
# Maithili
# Manipuri
# Santhali
# Urdu
# Kashmiri
# In how many languages AWW can enter the data while filling up the form?
# There are limited fields for data entry. Name is required to be entered in English language and for other fields numeric values are required. Most of the features are provided in check boxes or with drop down selection menu. Reports to be updated.
# How many different forms are there in Poshan Tracker App?
# There are 7 different types of forms for beneficiaries. This includes:
# Lactating mother
# Pregnant women
# Child 0-6 Months
# Child 6 Months to 3 Years
# Child 3 Years to 6 Years
# Adolescent Girls (11 Years-19 Years)
# What information to be added in AWC forms?
# AWW are required to enter details related to infrastructure present in a particular Anganwadi centre. This includes structure, basic amenities, facilities, sanitization, drinking water etc.
# How AWWS can sign up on the app if they are unable to register via their mobile numbers?
# In case AWW is unsuccessful in registering themselves there might be 2 possibilities:
# Their mobile number is not present in the data provided by the states to the MoWCD
# They are newly added to the system and their mobile number is not yet provided by the state cell to the MoWCD.
# In both the above cases state nodal officers are empowered to add/ edit/Activate/Deactivate any of the AWW.
# How can one access Poshan Tracker Dashboard?
# Poshan Tracker Dashboard can be accessed by signing onto the dashboard. Dashboard can be accessed by clicking the link https://poshantracker.in/admin Only nominated Nodal level officials at National, State, District, Project and Sector level are provided with a unique credentials to access the dashboard.
# How one can add AWW/AWCs?
# AWW/AWCs can only be added by nodal level official. Anybody in the above rank in the hierarchy.
# How many different types of reports can be generated over Poshan Tracker Dashboard?
# There are various reports that can be generated from
# General Reports:
# Number of app downloads
# Total number of Anganwadi centers registered
# Total number of beneficiaries registered (National/state/district/block wise)
# Total Number of pregnant women registered(National/state/district/block wise)
# Total Number of lactating mothers registered(National/state/district/block wise)
# Total Number of children (0-6months) registered(National/state/district/block wise)
# Total Number of children (6months-3years) registered(National/state/district/ block wise)
# Total Number of children (3-6years) registered(National/state/district/ block wise)
# Maternal and child nutrition:
# How many beneficiaries got THR in 21 days
# How many children breastfed exclusively in the first hour after delivery
# How many lactating mothers are given HCM
# Average level of calcium in children aged 3-6 years
# Average level of iron in children aged 3-6years
# Total number of vaccinations administered per month (block, district, state, national level)
# Vaccinations specific report administered per month (BCG/OPV/Hepatitis B/Rotavirus/Polio/Pneumococcal/Pentavalent
# AWC infrastructure:
# Number of AWCs (block, district, state, national level)
# Total number of Balvatikas (block district, state, national level)
# Total number of AWCs (block, district, state, national level) with clean drinking water
# Total number of AWCs (block, district, state, national level) with working weighing scale
# Total number of AWCs (block, district, state, national level) with electricity
# Total number of AWCs that are government owned
# Total number of AWCs that are privately owned
# How to contact Poshan Tracker Team?
# Poshan Tracker Team can be contacted by sending emails at support-poshantrackr@gov.in. For handholding and support we are also available over Video Conference each day 4:15 PM to 5:15 PM.
# Can a beneficiary register directly using application.
# Currently a beneficiary can register by the help of an AWW
# Who is a beneficiary?
# There are 6 categories for beneficiaries
# Pregnant Women
# Lactating Mother
# Children from 0 to 6 months
# Children from 6 months to 3 years
# Children from 3 years to 6 years
# Adolescent girls
# Can a beneficiary change his/her AWC?
# An AWW can use â€˜Migrate Beneficiaryâ€™ option to migrate a beneficiary from one AWC to another AWC basis their Aadhaar number.
# What is the eligibility of a beneficiary?
# A beneficiary is eligible for THR for at least 21 days in a month.
# Who is eligible for Take Home Ration?
# Pregnant Women, Lactating Mothers, Children from 6 months to 3 years and adolescent girls.
# Where can I enquire about take home ration?
# Please contact your respective Anganwadi worker.
# Who is eligible for additional supplementary food.
# Children who are identified as deficit on nutrition are eligible for additional food supplements.
# What is the eligibility of a beneficiary?
# A beneficiary is eligible for HCM for at least 21 days in a month.
# Who is eligible for Hot Cooked Meal?
# Children in the age group of 3 years to 6 years
# Where can I enquire about Hot Cooked Meal?
# Please contact your respective Anganwadi Centre.
# Who is eligible for additional supplementary food?
# Children who are identified as deficit on nutrition are eligible for additional food supplements.

# %%
print(contents)
# Out:
# What is Poshan Abhiyaan?
# Poshan Abhiyaan is Indiaâ€™s flagship programme to improve nutritional outcomes for children, adolescents, pregnant women and lactating mothers by leveraging technology, a targeted approach and convergence.
# What is the purpose of Launching Poshan Tracker?
# The purpose of POSHAN Tracker application is to provide a 360-degree view of the activities of the Anganwadi Centre (AWC), service deliveries of Anganwadi Workers (AWWs) and complete beneficiary management for pregnant women, lactating mothers and children. The proposed system should enable real-time monitoring and tracking of all AWCs, AWWs and beneficiaries on the defined indicators.
# How can one Download Poshan Tracker App?
# Poshan Tracker App is available over Google playstore https://play.google.com/store/apps/details?id=com.poshantracker
# Is poshan trackers app available over Apple I Store also?
# No, Poshan Tracker is available only for Android version
# What is the minimum requirement to install Poshan Tracker App in mobile?
# Poshan Tracker App can only be installed in Android Phone with Android version 6.0 and above.
# Can App be accessed without internet?
# App can be accessed offline, currently daily tracking feature is available for offline data entry. Offline mode can store latest 3 days data.
# Who are the target userbase of Poshan Tracker App?
# Poshan Tracker App is meant for Aanganwadi workers, Anganwadi centers to enter beneficiaries data in the forms. It is not at all developed for general public.
# How to Login in Poshan Tracker App?
# AWWs are requested to enter their mobile numbers in the Login screen. An OTP will be sent to your registered mobile number, post which you are required too set your MPIN.
# What is MPIN?
# MPIN is a 4 digits passcode which is set by an Anganwadi worker while registering over the Poshan Tracker App.
# How to set MPIN?
# MPIN can be set by respective Anganwadi worker by requesting an OTP against his/her mobile number. If Mobile number is already present in the database, the respective Anganwadi person will receive 4 digits OTP on registered mobile number. Post entering the OTP, AWW can easily set customized MPIN.
# When and how to use MPIN?
# While login to the Poshan Tracker App, AWWs are required to enter the MPIN set by them. This MPIN will act as a passcode to run the Poshan Tracker App and entering the information in the beneficiaries forms.
# How to Reset MPIN?
# MPIN can be easily reset by any AWW/AWC user. You are required to click on Forgot MPIN, and enter your registered mobile number. You will receive and OTP on your registered mobile number and you can ealily reset your MPIN
# In How many languages the Poshan Tracker App is available?
# Poshan Tracker App is available in 22 different languages
# The various languages available are:
# English
# Hindi
# Gujarati
# Punjabi
# Marathi
# Bangla
# Kannada
# Tamil
# Telugu
# Malyalam
# Odia
# Assamese
# Nepali
# Dogri
# Konkani
# Sindhi
# Bodo
# Maithili
# Manipuri
# Santhali
# Urdu
# Kashmiri
# In how many languages AWW can enter the data while filling up the form?
# There are limited fields for data entry. Name is required to be entered in English language and for other fields numeric values are required. Most of the features are provided in check boxes or with drop down selection menu. Reports to be updated.
# How many different forms are there in Poshan Tracker App?
# There are 7 different types of forms for beneficiaries. This includes:
# Lactating mother
# Pregnant women
# Child 0-6 Months
# Child 6 Months to 3 Years
# Child 3 Years to 6 Years
# Adolescent Girls (11 Years-19 Years)
# What information to be added in AWC forms?
# AWW are required to enter details related to infrastructure present in a particular Anganwadi centre. This includes structure, basic amenities, facilities, sanitization, drinking water etc.
# How AWWS can sign up on the app if they are unable to register via their mobile numbers?
# In case AWW is unsuccessful in registering themselves there might be 2 possibilities:
# Their mobile number is not present in the data provided by the states to the MoWCD
# They are newly added to the system and their mobile number is not yet provided by the state cell to the MoWCD.
# In both the above cases state nodal officers are empowered to add/ edit/Activate/Deactivate any of the AWW.
# How can one access Poshan Tracker Dashboard?
# Poshan Tracker Dashboard can be accessed by signing onto the dashboard. Dashboard can be accessed by clicking the link https://poshantracker.in/admin Only nominated Nodal level officials at National, State, District, Project and Sector level are provided with a unique credentials to access the dashboard.
# How one can add AWW/AWCs?
# AWW/AWCs can only be added by nodal level official. Anybody in the above rank in the hierarchy.
# How many different types of reports can be generated over Poshan Tracker Dashboard?
# There are various reports that can be generated from
# General Reports:
# Number of app downloads
# Total number of Anganwadi centers registered
# Total number of beneficiaries registered (National/state/district/block wise)
# Total Number of pregnant women registered(National/state/district/block wise)
# Total Number of lactating mothers registered(National/state/district/block wise)
# Total Number of children (0-6months) registered(National/state/district/block wise)
# Total Number of children (6months-3years) registered(National/state/district/ block wise)
# Total Number of children (3-6years) registered(National/state/district/ block wise)
# Maternal and child nutrition:
# How many beneficiaries got THR in 21 days
# How many children breastfed exclusively in the first hour after delivery
# How many lactating mothers are given HCM
# Average level of calcium in children aged 3-6 years
# Average level of iron in children aged 3-6years
# Total number of vaccinations administered per month (block, district, state, national level)
# Vaccinations specific report administered per month (BCG/OPV/Hepatitis B/Rotavirus/Polio/Pneumococcal/Pentavalent
# AWC infrastructure:
# Number of AWCs (block, district, state, national level)
# Total number of Balvatikas (block district, state, national level)
# Total number of AWCs (block, district, state, national level) with clean drinking water
# Total number of AWCs (block, district, state, national level) with working weighing scale
# Total number of AWCs (block, district, state, national level) with electricity
# Total number of AWCs that are government owned
# Total number of AWCs that are privately owned
# How to contact Poshan Tracker Team?
# Poshan Tracker Team can be contacted by sending emails at support-poshantrackr@gov.in. For handholding and support we are also available over Video Conference each day 4:15 PM to 5:15 PM.
# Can a beneficiary register directly using application.
# Currently a beneficiary can register by the help of an AWW
# Who is a beneficiary?
# There are 6 categories for beneficiaries
# Pregnant Women
# Lactating Mother
# Children from 0 to 6 months
# Children from 6 months to 3 years
# Children from 3 years to 6 years
# Adolescent girls
# Can a beneficiary change his/her AWC?
# An AWW can use â€˜Migrate Beneficiaryâ€™ option to migrate a beneficiary from one AWC to another AWC basis their Aadhaar number.
# What is the eligibility of a beneficiary?
# A beneficiary is eligible for THR for at least 21 days in a month.
# Who is eligible for Take Home Ration?
# Pregnant Women, Lactating Mothers, Children from 6 months to 3 years and adolescent girls.
# Where can I enquire about take home ration?
# Please contact your respective Anganwadi worker.
# Who is eligible for additional supplementary food.
# Children who are identified as deficit on nutrition are eligible for additional food supplements.
# What is the eligibility of a beneficiary?
# A beneficiary is eligible for HCM for at least 21 days in a month.
# Who is eligible for Hot Cooked Meal?
# Children in the age group of 3 years to 6 years
# Where can I enquire about Hot Cooked Meal?
# Please contact your respective Anganwadi Centre.
# Who is eligible for additional supplementary food?
# Children who are identified as deficit on nutrition are eligible for additional food supplements.

# %%
file = open("faq.txt", "rt")
contents = file.read()
words = contents.split()

print('Number of words in text file :', len(words))
# Out:
# Number of words in text file : 1245

# %%
number_of_characters = len(contents)
print('Number of characters in text file :', number_of_characters)
# Out:
# Number of characters in text file : 8042

# %%
#with open(fname, 'r') as f:
file = open("faq.txt", "rt")
contents = file.read()
num_lines = 0
for line in file:
    num_lines += line.count(".")

# %%
print(num_lines)
# Out:
# 0

# %%
fname = "faq.txt"

num_lines = 0
num_words = 0
num_chars = 0

with open(fname, 'r') as f:
    for line in f:
        words = line.split()

        num_lines += line.count(".")
        num_words += len(words)
        num_chars += len(line.replace(' ', ''))

# %%
print(num_lines)
print(num_words)
print(num_chars)
# Out:
# 49
# 1245
# 6924

# %%
with open(r'faq1.txt', encoding="utf8") as f:
    contents = f.read()
    print(contents)
# Out:
# पोषण अभियान क्या है?
# पोषण अभियान, एक लक्षित दृष्टिकोण और अभिसरण द्वारा बच्चों, किशोरों, गर्भवती महिलाओं और स्तनपान कराने वाली माताओं के लिए पोषण संबंधी परिणामों में सुधार करने के लिए भारत का प्रमुख कार्यक्रम है।
# पोषण ट्रैकर लॉन्च करने का उद्देश्य क्या है?
# पोषण ट्रैकर एप्लिकेशन का उद्देश्य आंगनवाड़ी केंद्र (एडब्ल्यूसी), आंगनवाड़ी कर्मचारी (एडब्ल्यूडब्ल्यू) की सेवा प्रदान करने वाली गतिविधियों और गर्भवती महिलाओं, स्तनपान कराने वाली माताओं और बच्चों के लिए पूर्ण लाभार्थी प्रबंधन की गतिविधियों का 360 डिग्री दृश्य प्रदान करना है। प्रस्तावित प्रणाली को सभी एडब्ल्यूसी, एडब्ल्यू डब्ल्यू और लाभार्थियों को परिभाषित संकेतक पर वास्तविक समय की निगरानी और समझना सक्षम करना चाहिए।
# पोषण ट्रैकर ऐप को कैसे डाउनलोड किया जा सकता है?
# पोषण ट्रैकर ऐप गूगल प्ले स्टोर https://play.google.com/store/apps/details?id=com.poshantracker पर उपलब्ध है।
# क्या ऐप्पल आई स्टोर पर भी पोषण ट्रैक ऐप उपलब्ध है?
# कोई पोषण ट्रैकर केवल एंड्रॉइड संस्करण के लिए उपलब्ध नहीं है।
# मोबाइल में पोषण ट्रैकर ऐप इंस्टॉल करने के लिए न्यूनतम आवश्यकता क्या है?
# पोषण ट्रैकर ऐप केवल एंड्रॉइड फोन में एंड्रॉइड संस्करण 6.0 और इसके बाद के संस्करण में स्थापित किया जा सकता है।
# क्या ऐप को इंटरनेट के बिना अभिगम किया जा सकता है?
# कोई भी ऐप वैध इंटरनेट कनेक्शन के बिना काम नहीं करती है।
# पोषण ट्रैकर ऐप के टारगेट यूज़रबेस कौन हैं?
# पोषण ट्रैकर ऐप आंगनवाड़ी कार्यकर्ताओं के लिए है जो आंगनवाड़ी केंद्रों के लाभार्थियों के डेटा को प्रपत्रों में दर्ज करता है। यह आम जनता के लिए बिल्कुल भी विकसित नहीं है।
# पोषण ट्रैकर ऐप में कैसे लॉगिन करें?
# एडब्ल्यूडब्ल्यू से अनुरोध है कि लॉगिन स्क्रीन में अपने मोबाइल नंबर दर्ज करें। आपके पंजीकृत मोबाइल नंबर पर एक ओटीपी भेजा जाएगा जिसकी आपको आवश्यकता है, अपना एमपीआईएन स्थापित करें।
# एमपीआईएन क्या है?
# जो आंगनवाड़ी कार्यकर्ता द्वारा पोषण ट्रैकर ऐप पर पंजीकरण करते समय निर्धारित किया जाता है।
# एमपीआईएन कैसे निर्धारित करें?
# एमपीआईएन को संबंधित आंगनवाड़ी कार्यकर्ता द्वारा अपने मोबाइल नंबर पर ओटीपी के लिए अनुरोध किया जा सकता है। यदि मोबाइल नंबर पहले से ही डेटाबेस में मौजूद है, तो संबंधित आंगनवाड़ी व्यक्ति को पंजीकृत मोबाइल नंबर पर 4 अंकों का ओटीपी प्राप्त होगा। ओटीपी दर्ज करने के बाद, एडब्ल्यूडब्ल्यू आसानी से अनुकूलित एमपीआईएन निर्धारित कर सकता है।
# एमपीआईएन कब और कैसे इस्तेमाल करें?
# पोषण ट्रैकर ऐप में लॉगिन करते समय, एडब्ल्यूडब्ल्यू को उनके द्वारा निर्धारित एमपीआई में प्रवेश करना होता है। यह एमपीआईएन पोषण ट्रैकर ऐप चलाने और लाभार्थियों के फॉर्म में जानकारी दर्ज करने के लिए एक पासकोड के रूप में कार्य करेगा।
# एमपीआईएन कैसे दोबारा निर्धारित करें?
# एमपीआईएन को किसी भी एडब्ल्यूडब्ल्यू / एडब्ल्यूसी उपयोगकर्ता द्वारा आसानी से दोबारा निर्धारित किया जा सकता है। आपको भूल गए एमपीआईएन पर क्लिक करना होगा, और अपना पंजीकृत मोबाइल नंबर दर्ज करना होगा। आपको अपने पंजीकृत मोबाइल नंबर पर ओटीपी प्राप्त होगा और आप अपने एमपीआईएन को आसानी से दोबारा निर्धारित कर सकते हैं।
# पोषण ट्रैकर ऐप कितनी भाषाओं में उपलब्ध है?
# पोषण ट्रैकर ऐप 22 अलग-अलग भाषाओं में उपलब्ध है।
# उपलब्ध विभिन्न भाषाएँ हैं:
# अंग्रेजी
# हिंदी
# गुजराती
# पंजाबी
# मराठी
# बंगला
# कन्नड़
# तमिल
# तेलुगु
# मलायलम
# ओडिया
# असमिया
# Nepali
# Dogri
# Konkani
# Sindhi
# Bodo
# Maithili
# Manipuri
# Santhali
# Urdu
# Kashmiri
# फॉर्म भरते समय एडब्ल्यूडब्ल्यू या एडब्ल्यूसी कितनी भाषाओं में डेटा दर्ज कर सकती है?
# एडब्ल्यूडब्ल्यू अंग्रेजी भाषा में ही फॉर्म भर सकता है।
# पोषण ट्रैकर ऐप में कितने विभिन्न रूप हैं?
# लाभार्थियों के लिए 7 विभिन्न प्रकार के फॉर्म हैं। इसमें शामिल हैं:
# स्तनपान कराने वाली मां
# गर्भवती महिलाएं
# बच्चा 0-6 महीने
# बच्चा 6 महीने से 3 साल तक
# बाल 3 साल से 6 साल
# किशोर लड़कियां (11 साल -19 साल)
# एडब्ल्यूसी फॉर्म में कौन सी जानकारी जोड़ी जानी चाहिए?
# एडब्ल्यूडब्ल्यू एक विशेष आंगनवाड़ी केंद्र में मौजूद बुनियादी ढांचे से संबंधित विवरण दर्ज करने के लिए आवश्यक हैं। इसमें संरचना, बुनियादी सुविधाएं, सुख-सुविधाएँ, स्वच्छता, पेयजल आदि शामिल हैं।
# अगर वे अपने मोबाइल नंबरों के माध्यम से पंजीकरण करने में असमर्थ हैं, तो एडब्ल्यूडब्ल्यू ऐप पर साइन अप कैसे कर सकता है?
# यदि एडब्ल्यूडब्ल्यू खुद को पंजीकृत करने में असफल है तो 2 संभावनाएं हो सकती हैं:
# राज्यों द्वारा एमओडब्ल्यूसीडी को उपलब्ध कराए गए डेटा में उनका मोबाइल नंबर मौजूद नहीं है।
# वे प्रणाली में नए जोड़े गए हैं और उनका मोबाइल नंबर अभी तक राज्य सेल द्वारा एमओडब्ल्यूसीडी को प्रदान नहीं किया गया है।
# उपरोक्त दोनों मामलों में राज्य नोडल अधिकारियों को एडब्ल्यूडब्ल्यू में से किसी को जोड़ने / संपादित / सक्रिय / निष्क्रिय करने का अधिकार है।
# पोषण ट्रैकर डैशबोर्ड तक कोई कैसे पहुंच सकता है?
# पोषण ट्रैकर डैशबोर्ड को डैशबोर्ड पर साइन करके पहुँचा जा सकता है। डैशबोर्ड को लिंक पर क्लिक करके एक्सेस किया जा सकता है https://poshantracker.in/admin केवल नेशनल में नामित नोडल स्तर के अधिकारी डैशबोर्ड तक पहुँचने के लिए राज्य, जिला, परियोजना और सेक्टर स्तर को एक अद्वितीय प्रमाणिकता प्रदान की जाती है।
# कोई एडब्ल्यूडब्ल्यू / एडब्ल्यूसी कैसे जोड़ सकता है?
# एडब्ल्यूडब्ल्यू / एडब्ल्यूसी को केवल नोडल स्तर के अधिकारी द्वारा जोड़ा जा सकता है। पदानुक्रम में ऊपर की ओर कोई भी। राष्ट्रीय स्तर के उपयोगकर्ता के रूप में राज्य, जिला, परियोजना और क्षेत्र स्तर उपयोगकर्ता बना सकते हैं। राज्य स्तर का उपयोगकर्ता जिला, परियोजना और क्षेत्र स्तर का उपयोगकर्ता बना सकता है, जिला स्तर का उपयोगकर्ता परियोजना और क्षेत्र स्तर का उपयोगकर्ता बना सकता है, परियोजना स्तर का उपयोगकर्ता क्षेत्र का उपयोगकर्ता बना सकता है।
# पोषण ट्रैकर डैशबोर्ड पर कितने विभिन्न प्रकार के अभिलेख उत्पन्न की जा सकती हैं?
# ऐसी विभिन्न रिपोर्टें हैं जो
# से उत्पन्न हो सकती हैं सामान्य रिपोर्ट:
# ऐप डाउनलोड की संख्या
# पंजीकृत आंगनवाड़ी केंद्रों की कुल संख्या
# पंजीकृत लाभार्थियों की कुल संख्या (राष्ट्रीय / राज्य / जिला / ब्लॉक वार)
# पंजीकृत गर्भवती महिलाओं की कुल संख्या (राष्ट्रीय / राज्य / जिला / ब्लॉकवार)
# पंजीकृत माताओं की कुल संख्या (राष्ट्रीय / राज्य / जिला / ब्लॉक वार)
# पंजीकृत बच्चों की कुल संख्या (0-6 महीने) पंजीकृत (राष्ट्रीय / राज्य / जिला / ब्लॉकवार)
# पंजीकृत बच्चों की कुल संख्या (6 महीने) जिला / ब्लॉक वार)
# मातृ एवं शिशु पोषण:
# 21 दिनों में कितने लाभार्थियों को THR मिला
# कितने बच्चे स्तनपान करते हैं प्रसव के बाद पहले घंटे में विशेष रूप से
# कितनी स्तनपान कराने वाली माताओं को एचसीएम दिया जाता है
# कितने बच्चे विशेष रूप से प्राथमिकी में स्तनपान करते हैं प्रसव के बाद घंटे
# 3-6 वर्ष की आयु के बच्चों में कैल्शियम का औसत स्तर
# 3-6 वर्ष की आयु के बच्चों में लोहे का औसत स्तर
# टीकाकरण की कुल संख्या प्रति माह प्रशासित (ब्लॉक, जिला, राज्य, राष्ट्रीय स्तर)
# प्रति माह प्रशासित विशिष्ट रिपोर्ट (बीसीजी / ओपीवी / हेपेटाइटिस बी / रोटावायरस / पोलियो / न्यूमोकोकल / पेंटालेंटल)
# एडब्ल्यूसी अवसंरचना:
# एडब्ल्यूसी की संख्या (ब्लॉक, जिला, राज्य, राष्ट्रीय स्तर)
# बालविकास की कुल संख्या (ब्लॉक जिला, राज्य, राष्ट्रीय स्तर)
# स्वच्छ पेयजल के साथ एडब्ल्यूसी (ब्लॉक, जिला, राज्य, राष्ट्रीय स्तर) की कुल संख्या
# कार्य भार पैमाने के साथ एडब्ल्यूसी (ब्लॉक, जिला, राज्य, राष्ट्रीय स्तर) की कुल संख्या
# बिजली के साथ एडब्ल्यूसी (ब्लॉक, जिला, राज्य, राष्ट्रीय स्तर) की कुल संख्या
# सरकार की स्वामित्व वाली एडब्ल्यूसी की कुल संख्या
# निजी तौर पर होने वाले एडब्ल्यूसी की कुल संख्या स्वामित्व
# पोशन ट्रैकर समूह से कैसे संपर्क करें?
# पोषण ट्रैकर समूह से support-poshantrackr@gov.in पर ईमेल भेजकर संपर्क किया जा सकता है। आपके सहयोग और समर्थन के लिए हम प्रतिदिन शाम 4:15 बजे से शाम 5:15 बजे तक वीडियो कॉन्फ्रेंस पर भी उपलब्ध हैं।

# %%
words = contents.split()

print('Number of words in text file :', len(words))
# Out:
# Number of words in text file : 1182

# %%
number_of_characters = len(contents)
print('Number of characters in text file :', number_of_characters)
# Out:
# Number of characters in text file : 6856

# %%
num_lines = 0
num_words = 0
num_chars = 0

with open(r'faq1.txt', encoding="utf8") as f:
    for line in f:
        words = line.split()

        num_lines += line.count(".")
        num_words += len(words)
        num_chars += len(line.replace(' ', ''))

# %%
print(num_lines)
print(num_words)
print(num_chars)
# Out:
# 6
# 1182
# 5772

# %%
# !pip install indic-nlp-library
# Out:
# Collecting indic-nlp-library
#   Downloading indic_nlp_library-0.91-py3-none-any.whl (40 kB)
# Requirement already satisfied: pandas in c:\users\amruta\anaconda3\lib\site-packages (from indic-nlp-library) (1.3.4)
# Collecting sphinx-rtd-theme
#   Downloading sphinx_rtd_theme-1.2.0-py2.py3-none-any.whl (2.8 MB)
# Collecting sphinx-argparse
#   Downloading sphinx_argparse-0.4.0-py3-none-any.whl (12 kB)
# Collecting morfessor
#   Downloading Morfessor-2.0.6-py3-none-any.whl (35 kB)
# Requirement already satisfied: numpy in c:\users\amruta\anaconda3\lib\site-packages (from indic-nlp-library) (1.20.3)
# Requirement already satisfied: pytz>=2017.3 in c:\users\amruta\anaconda3\lib\site-packages (from pandas->indic-nlp-library) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\amruta\anaconda3\lib\site-packages (from pandas->indic-nlp-library) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\amruta\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas->indic-nlp-library) (1.16.0)
# Requirement already satisfied: sphinx>=1.2.0 in c:\users\amruta\anaconda3\lib\site-packages (from sphinx-argparse->indic-nlp-library) (4.2.0)
# Requirement already satisfied: sphinxcontrib-applehelp in c:\users\amruta\anaconda3\lib\site-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (1.0.2)
# Requirement already satisfied: sphinxcontrib-devhelp in c:\users\amruta\anaconda3\lib\site-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (1.0.2)
# Requirement already satisfied: sphinxcontrib-jsmath in c:\users\amruta\anaconda3\lib\site-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (1.0.1)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.0 in c:\users\amruta\anaconda3\lib\site-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2.0.0)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.5 in c:\users\amruta\anaconda3\lib\site-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (1.1.5)
# Requirement already satisfied: sphinxcontrib-qthelp in c:\users\amruta\anaconda3\lib\site-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (1.0.3)
# Requirement already satisfied: Jinja2>=2.3 in c:\users\amruta\anaconda3\lib\site-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2.11.3)
# Requirement already satisfied: Pygments>=2.0 in c:\users\amruta\anaconda3\lib\site-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2.10.0)
# Requirement already satisfied: docutils<0.18,>=0.14 in c:\users\amruta\anaconda3\lib\site-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (0.17.1)
# Requirement already satisfied: snowballstemmer>=1.1 in c:\users\amruta\anaconda3\lib\site-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2.1.0)
# Requirement already satisfied: babel>=1.3 in c:\users\amruta\anaconda3\lib\site-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2.9.1)
# Requirement already satisfied: alabaster<0.8,>=0.7 in c:\users\amruta\anaconda3\lib\site-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (0.7.12)
# Requirement already satisfied: imagesize in c:\users\amruta\anaconda3\lib\site-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (1.2.0)
# Requirement already satisfied: requests>=2.5.0 in c:\users\amruta\anaconda3\lib\site-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2.26.0)
# Requirement already satisfied: setuptools in c:\users\amruta\anaconda3\lib\site-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (58.0.4)
# Requirement already satisfied: packaging in c:\users\amruta\anaconda3\lib\site-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (21.0)
# Requirement already satisfied: colorama>=0.3.5 in c:\users\amruta\anaconda3\lib\site-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (0.4.4)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\amruta\anaconda3\lib\site-packages (from Jinja2>=2.3->sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (1.1.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\amruta\anaconda3\lib\site-packages (from requests>=2.5.0->sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\amruta\anaconda3\lib\site-packages (from requests>=2.5.0->sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\amruta\anaconda3\lib\site-packages (from requests>=2.5.0->sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (3.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\amruta\anaconda3\lib\site-packages (from requests>=2.5.0->sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (1.26.7)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\amruta\anaconda3\lib\site-packages (from packaging->sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (3.0.4)
# Collecting sphinxcontrib-jquery!=3.0.0,>=2.0.0
#   Downloading sphinxcontrib_jquery-4.1-py2.py3-none-any.whl (121 kB)
# Installing collected packages: sphinxcontrib-jquery, sphinx-rtd-theme, sphinx-argparse, morfessor, indic-nlp-library
# Successfully installed indic-nlp-library-0.91 morfessor-2.0.6 sphinx-argparse-0.4.0 sphinx-rtd-theme-1.2.0 sphinxcontrib-jquery-4.1

# %%
from indicnlp.transliterate.unicode_transliterate import UnicodeIndicTransliterator
input_text='अमृता'
print(UnicodeIndicTransliterator.transliterate(input_text,"hi","te"))
# Out:
# అమృతా

# %%
from indicnlp.transliterate.unicode_transliterate import UnicodeIndicTransliterator
with open(r'faq1.txt', encoding="utf8") as f:
    contents = f.read()
    print(UnicodeIndicTransliterator.transliterate(contents,"hi","en"))
# Out:
# पोषण अभियान क्या है?
# पोषण अभियान, एक लक्षित दृष्टिकोण और अभिसरण द्वारा बच्चों, किशोरों, गर्भवती महिलाओं और स्तनपान कराने वाली माताओं के लिए पोषण संबंधी परिणामों में सुधार करने के लिए भारत का प्रमुख कार्यक्रम है।
# पोषण ट्रैकर लॉन्च करने का उद्देश्य क्या है?
# पोषण ट्रैकर एप्लिकेशन का उद्देश्य आंगनवाड़ी केंद्र (एडब्ल्यूसी), आंगनवाड़ी कर्मचारी (एडब्ल्यूडब्ल्यू) की सेवा प्रदान करने वाली गतिविधियों और गर्भवती महिलाओं, स्तनपान कराने वाली माताओं और बच्चों के लिए पूर्ण लाभार्थी प्रबंधन की गतिविधियों का 360 डिग्री दृश्य प्रदान करना है। प्रस्तावित प्रणाली को सभी एडब्ल्यूसी, एडब्ल्यू डब्ल्यू और लाभार्थियों को परिभाषित संकेतक पर वास्तविक समय की निगरानी और समझना सक्षम करना चाहिए।
# पोषण ट्रैकर ऐप को कैसे डाउनलोड किया जा सकता है?
# पोषण ट्रैकर ऐप गूगल प्ले स्टोर https://play.google.com/store/apps/details?id=com.poshantracker पर उपलब्ध है।
# क्या ऐप्पल आई स्टोर पर भी पोषण ट्रैक ऐप उपलब्ध है?
# कोई पोषण ट्रैकर केवल एंड्रॉइड संस्करण के लिए उपलब्ध नहीं है।
# मोबाइल में पोषण ट्रैकर ऐप इंस्टॉल करने के लिए न्यूनतम आवश्यकता क्या है?
# पोषण ट्रैकर ऐप केवल एंड्रॉइड फोन में एंड्रॉइड संस्करण 6.0 और इसके बाद के संस्करण में स्थापित किया जा सकता है।
# क्या ऐप को इंटरनेट के बिना अभिगम किया जा सकता है?
# कोई भी ऐप वैध इंटरनेट कनेक्शन के बिना काम नहीं करती है।
# पोषण ट्रैकर ऐप के टारगेट यूज़रबेस कौन हैं?
# पोषण ट्रैकर ऐप आंगनवाड़ी कार्यकर्ताओं के लिए है जो आंगनवाड़ी केंद्रों के लाभार्थियों के डेटा को प्रपत्रों में दर्ज करता है। यह आम जनता के लिए बिल्कुल भी विकसित नहीं है।
# पोषण ट्रैकर ऐप में कैसे लॉगिन करें?
# एडब्ल्यूडब्ल्यू से अनुरोध है कि लॉगिन स्क्रीन में अपने मोबाइल नंबर दर्ज करें। आपके पंजीकृत मोबाइल नंबर पर एक ओटीपी भेजा जाएगा जिसकी आपको आवश्यकता है, अपना एमपीआईएन स्थापित करें।
# एमपीआईएन क्या है?
# जो आंगनवाड़ी कार्यकर्ता द्वारा पोषण ट्रैकर ऐप पर पंजीकरण करते समय निर्धारित किया जाता है।
# एमपीआईएन कैसे निर्धारित करें?
# एमपीआईएन को संबंधित आंगनवाड़ी कार्यकर्ता द्वारा अपने मोबाइल नंबर पर ओटीपी के लिए अनुरोध किया जा सकता है। यदि मोबाइल नंबर पहले से ही डेटाबेस में मौजूद है, तो संबंधित आंगनवाड़ी व्यक्ति को पंजीकृत मोबाइल नंबर पर 4 अंकों का ओटीपी प्राप्त होगा। ओटीपी दर्ज करने के बाद, एडब्ल्यूडब्ल्यू आसानी से अनुकूलित एमपीआईएन निर्धारित कर सकता है।
# एमपीआईएन कब और कैसे इस्तेमाल करें?
# पोषण ट्रैकर ऐप में लॉगिन करते समय, एडब्ल्यूडब्ल्यू को उनके द्वारा निर्धारित एमपीआई में प्रवेश करना होता है। यह एमपीआईएन पोषण ट्रैकर ऐप चलाने और लाभार्थियों के फॉर्म में जानकारी दर्ज करने के लिए एक पासकोड के रूप में कार्य करेगा।
# एमपीआईएन कैसे दोबारा निर्धारित करें?
# एमपीआईएन को किसी भी एडब्ल्यूडब्ल्यू / एडब्ल्यूसी उपयोगकर्ता द्वारा आसानी से दोबारा निर्धारित किया जा सकता है। आपको भूल गए एमपीआईएन पर क्लिक करना होगा, और अपना पंजीकृत मोबाइल नंबर दर्ज करना होगा। आपको अपने पंजीकृत मोबाइल नंबर पर ओटीपी प्राप्त होगा और आप अपने एमपीआईएन को आसानी से दोबारा निर्धारित कर सकते हैं।
# पोषण ट्रैकर ऐप कितनी भाषाओं में उपलब्ध है?
# पोषण ट्रैकर ऐप 22 अलग-अलग भाषाओं में उपलब्ध है।
# उपलब्ध विभिन्न भाषाएँ हैं:
# अंग्रेजी
# हिंदी
# गुजराती
# पंजाबी
# मराठी
# बंगला
# कन्नड़
# तमिल
# तेलुगु
# मलायलम
# ओडिया
# असमिया
# Nepali
# Dogri
# Konkani
# Sindhi
# Bodo
# Maithili
# Manipuri
# Santhali
# Urdu
# Kashmiri
# फॉर्म भरते समय एडब्ल्यूडब्ल्यू या एडब्ल्यूसी कितनी भाषाओं में डेटा दर्ज कर सकती है?
# एडब्ल्यूडब्ल्यू अंग्रेजी भाषा में ही फॉर्म भर सकता है।
# पोषण ट्रैकर ऐप में कितने विभिन्न रूप हैं?
# लाभार्थियों के लिए 7 विभिन्न प्रकार के फॉर्म हैं। इसमें शामिल हैं:
# स्तनपान कराने वाली मां
# गर्भवती महिलाएं
# बच्चा 0-6 महीने
# बच्चा 6 महीने से 3 साल तक
# बाल 3 साल से 6 साल
# किशोर लड़कियां (11 साल -19 साल)
# एडब्ल्यूसी फॉर्म में कौन सी जानकारी जोड़ी जानी चाहिए?
# एडब्ल्यूडब्ल्यू एक विशेष आंगनवाड़ी केंद्र में मौजूद बुनियादी ढांचे से संबंधित विवरण दर्ज करने के लिए आवश्यक हैं। इसमें संरचना, बुनियादी सुविधाएं, सुख-सुविधाएँ, स्वच्छता, पेयजल आदि शामिल हैं।
# अगर वे अपने मोबाइल नंबरों के माध्यम से पंजीकरण करने में असमर्थ हैं, तो एडब्ल्यूडब्ल्यू ऐप पर साइन अप कैसे कर सकता है?
# यदि एडब्ल्यूडब्ल्यू खुद को पंजीकृत करने में असफल है तो 2 संभावनाएं हो सकती हैं:
# राज्यों द्वारा एमओडब्ल्यूसीडी को उपलब्ध कराए गए डेटा में उनका मोबाइल नंबर मौजूद नहीं है।
# वे प्रणाली में नए जोड़े गए हैं और उनका मोबाइल नंबर अभी तक राज्य सेल द्वारा एमओडब्ल्यूसीडी को प्रदान नहीं किया गया है।
# उपरोक्त दोनों मामलों में राज्य नोडल अधिकारियों को एडब्ल्यूडब्ल्यू में से किसी को जोड़ने / संपादित / सक्रिय / निष्क्रिय करने का अधिकार है।
# पोषण ट्रैकर डैशबोर्ड तक कोई कैसे पहुंच सकता है?
# पोषण ट्रैकर डैशबोर्ड को डैशबोर्ड पर साइन करके पहुँचा जा सकता है। डैशबोर्ड को लिंक पर क्लिक करके एक्सेस किया जा सकता है https://poshantracker.in/admin केवल नेशनल में नामित नोडल स्तर के अधिकारी डैशबोर्ड तक पहुँचने के लिए राज्य, जिला, परियोजना और सेक्टर स्तर को एक अद्वितीय प्रमाणिकता प्रदान की जाती है।
# कोई एडब्ल्यूडब्ल्यू / एडब्ल्यूसी कैसे जोड़ सकता है?
# एडब्ल्यूडब्ल्यू / एडब्ल्यूसी को केवल नोडल स्तर के अधिकारी द्वारा जोड़ा जा सकता है। पदानुक्रम में ऊपर की ओर कोई भी। राष्ट्रीय स्तर के उपयोगकर्ता के रूप में राज्य, जिला, परियोजना और क्षेत्र स्तर उपयोगकर्ता बना सकते हैं। राज्य स्तर का उपयोगकर्ता जिला, परियोजना और क्षेत्र स्तर का उपयोगकर्ता बना सकता है, जिला स्तर का उपयोगकर्ता परियोजना और क्षेत्र स्तर का उपयोगकर्ता बना सकता है, परियोजना स्तर का उपयोगकर्ता क्षेत्र का उपयोगकर्ता बना सकता है।
# पोषण ट्रैकर डैशबोर्ड पर कितने विभिन्न प्रकार के अभिलेख उत्पन्न की जा सकती हैं?
# ऐसी विभिन्न रिपोर्टें हैं जो
# से उत्पन्न हो सकती हैं सामान्य रिपोर्ट:
# ऐप डाउनलोड की संख्या
# पंजीकृत आंगनवाड़ी केंद्रों की कुल संख्या
# पंजीकृत लाभार्थियों की कुल संख्या (राष्ट्रीय / राज्य / जिला / ब्लॉक वार)
# पंजीकृत गर्भवती महिलाओं की कुल संख्या (राष्ट्रीय / राज्य / जिला / ब्लॉकवार)
# पंजीकृत माताओं की कुल संख्या (राष्ट्रीय / राज्य / जिला / ब्लॉक वार)
# पंजीकृत बच्चों की कुल संख्या (0-6 महीने) पंजीकृत (राष्ट्रीय / राज्य / जिला / ब्लॉकवार)
# पंजीकृत बच्चों की कुल संख्या (6 महीने) जिला / ब्लॉक वार)
# मातृ एवं शिशु पोषण:
# 21 दिनों में कितने लाभार्थियों को THR मिला
# कितने बच्चे स्तनपान करते हैं प्रसव के बाद पहले घंटे में विशेष रूप से
# कितनी स्तनपान कराने वाली माताओं को एचसीएम दिया जाता है
# कितने बच्चे विशेष रूप से प्राथमिकी में स्तनपान करते हैं प्रसव के बाद घंटे
# 3-6 वर्ष की आयु के बच्चों में कैल्शियम का औसत स्तर
# 3-6 वर्ष की आयु के बच्चों में लोहे का औसत स्तर
# टीकाकरण की कुल संख्या प्रति माह प्रशासित (ब्लॉक, जिला, राज्य, राष्ट्रीय स्तर)
# प्रति माह प्रशासित विशिष्ट रिपोर्ट (बीसीजी / ओपीवी / हेपेटाइटिस बी / रोटावायरस / पोलियो / न्यूमोकोकल / पेंटालेंटल)
# एडब्ल्यूसी अवसंरचना:
# एडब्ल्यूसी की संख्या (ब्लॉक, जिला, राज्य, राष्ट्रीय स्तर)
# बालविकास की कुल संख्या (ब्लॉक जिला, राज्य, राष्ट्रीय स्तर)
# स्वच्छ पेयजल के साथ एडब्ल्यूसी (ब्लॉक, जिला, राज्य, राष्ट्रीय स्तर) की कुल संख्या
# कार्य भार पैमाने के साथ एडब्ल्यूसी (ब्लॉक, जिला, राज्य, राष्ट्रीय स्तर) की कुल संख्या
# बिजली के साथ एडब्ल्यूसी (ब्लॉक, जिला, राज्य, राष्ट्रीय स्तर) की कुल संख्या
# सरकार की स्वामित्व वाली एडब्ल्यूसी की कुल संख्या
# निजी तौर पर होने वाले एडब्ल्यूसी की कुल संख्या स्वामित्व
# पोशन ट्रैकर समूह से कैसे संपर्क करें?
# पोषण ट्रैकर समूह से support-poshantrackr@gov.in पर ईमेल भेजकर संपर्क किया जा सकता है। आपके सहयोग और समर्थन के लिए हम प्रतिदिन शाम 4:15 बजे से शाम 5:15 बजे तक वीडियो कॉन्फ्रेंस पर भी उपलब्ध हैं।

# %%
# import required modules
from indicnlp.transliterate.unicode_transliterate import UnicodeIndicTransliterator
import codecs

# read in the text file in Unicode format
with codecs.open(r'C:\Users\AMRUTA\Desktop\faq1.txt', encoding='utf-8') as f:
    hindi_text = f.read()

# transliterate the Hindi text to English using IndicNLP
english_text = UnicodeIndicTransliterator.transliterate(hindi_text, "hi", "te")

# print the translated text
print(english_text)
# Out:
# పోషణ అభియాన క్యా హై?
# పోషణ అభియాన, ఏక లక్షిత దృష్టికోణ ఔర అభిసరణ ద్వారా బచ్చోం, కిశోరోం, గర్భవతీ మహిలాఓం ఔర స్తనపాన కరానే వాలీ మాతాఓం కే లిఏ పోషణ సంబంధీ పరిణామోం మేం సుధార కరనే కే లిఏ భారత కా ప్రముఖ కార్యక్రమ హై।
# పోషణ ట్రైకర ల౉న్చ కరనే కా ఉద్దేశ్య క్యా హై?
# పోషణ ట్రైకర ఏప్లికేశన కా ఉద్దేశ్య ఆంగనవాడ఼ీ కేంద్ర (ఏడబ్ల్యూసీ), ఆంగనవాడ఼ీ కర్మచారీ (ఏడబ్ల్యూడబ్ల్యూ) కీ సేవా ప్రదాన కరనే వాలీ గతివిధియోం ఔర గర్భవతీ మహిలాఓం, స్తనపాన కరానే వాలీ మాతాఓం ఔర బచ్చోం కే లిఏ పూర్ణ లాభార్థీ ప్రబంధన కీ గతివిధియోం కా 360 డిగ్రీ దృశ్య ప్రదాన కరనా హై। ప్రస్తావిత ప్రణాలీ కో సభీ ఏడబ్ల్యూసీ, ఏడబ్ల్యూ డబ్ల్యూ ఔర లాభార్థియోం కో పరిభాషిత సంకేతక పర వాస్తవిక సమయ కీ నిగరానీ ఔర సమఝనా సక్షమ కరనా చాహిఏ।
# పోషణ ట్రైకర ఐప కో కైసే డాఉనలోడ కియా జా సకతా హై?
# పోషణ ట్రైకర ఐప గూగల ప్లే స్టోర https://play.google.com/store/apps/details?id=com.poshantracker పర ఉపలబ్ధ హై।
# క్యా ఐప్పల ఆఈ స్టోర పర భీ పోషణ ట్రైక ఐప ఉపలబ్ధ హై?
# కోఈ పోషణ ట్రైకర కేవల ఏండ్ర౉ఇడ సంస్కరణ కే లిఏ ఉపలబ్ధ నహీం హై।
# మోబాఇల మేం పోషణ ట్రైకర ఐప ఇంస్ట౉ల కరనే కే లిఏ న్యూనతమ ఆవశ్యకతా క్యా హై?
# పోషణ ట్రైకర ఐప కేవల ఏండ్ర౉ఇడ ఫోన మేం ఏండ్ర౉ఇడ సంస్కరణ 6.0 ఔర ఇసకే బాద కే సంస్కరణ మేం స్థాపిత కియా జా సకతా హై।
# క్యా ఐప కో ఇంటరనేట కే బినా అభిగమ కియా జా సకతా హై?
# కోఈ భీ ఐప వైధ ఇంటరనేట కనేక్శన కే బినా కామ నహీం కరతీ హై।
# పోషణ ట్రైకర ఐప కే టారగేట యూజ఼రబేస కౌన హైం?
# పోషణ ట్రైకర ఐప ఆంగనవాడ఼ీ కార్యకర్తాఓం కే లిఏ హై జో ఆంగనవాడ఼ీ కేంద్రోం కే లాభార్థియోం కే డేటా కో ప్రపత్రోం మేం దర్జ కరతా హై। యహ ఆమ జనతా కే లిఏ బిల్కుల భీ వికసిత నహీం హై।
# పోషణ ట్రైకర ఐప మేం కైసే ల౉గిన కరేం?
# ఏడబ్ల్యూడబ్ల్యూ సే అనురోధ హై కి ల౉గిన స్క్రీన మేం అపనే మోబాఇల నంబర దర్జ కరేం। ఆపకే పంజీకృత మోబాఇల నంబర పర ఏక ఓటీపీ భేజా జాఏగా జిసకీ ఆపకో ఆవశ్యకతా హై, అపనా ఏమపీఆఈఏన స్థాపిత కరేం।
# ఏమపీఆఈఏన క్యా హై?
# జో ఆంగనవాడ఼ీ కార్యకర్తా ద్వారా పోషణ ట్రైకర ఐప పర పంజీకరణ కరతే సమయ నిర్ధారిత కియా జాతా హై।
# ఏమపీఆఈఏన కైసే నిర్ధారిత కరేం?
# ఏమపీఆఈఏన కో సంబంధిత ఆంగనవాడ఼ీ కార్యకర్తా ద్వారా అపనే మోబాఇల నంబర పర ఓటీపీ కే లిఏ అనురోధ కియా జా సకతా హై। యది మోబాఇల నంబర పహలే సే హీ డేటాబేస మేం మౌజూద హై, తో సంబంధిత ఆంగనవాడ఼ీ వ్యక్తి కో పంజీకృత మోబాఇల నంబర పర 4 అంకోం కా ఓటీపీ ప్రాప్త హోగా। ఓటీపీ దర్జ కరనే కే బాద, ఏడబ్ల్యూడబ్ల్యూ ఆసానీ సే అనుకూలిత ఏమపీఆఈఏన నిర్ధారిత కర సకతా హై।
# ఏమపీఆఈఏన కబ ఔర కైసే ఇస్తేమాల కరేం?
# పోషణ ట్రైకర ఐప మేం ల౉గిన కరతే సమయ, ఏడబ్ల్యూడబ్ల్యూ కో ఉనకే ద్వారా నిర్ధారిత ఏమపీఆఈ మేం ప్రవేశ కరనా హోతా హై। యహ ఏమపీఆఈఏన పోషణ ట్రైకర ఐప చలానే ఔర లాభార్థియోం కే ఫ౉ర్మ మేం జానకారీ దర్జ కరనే కే లిఏ ఏక పాసకోడ కే రూప మేం కార్య కరేగా।
# ఏమపీఆఈఏన కైసే దోబారా నిర్ధారిత కరేం?
# ఏమపీఆఈఏన కో కిసీ భీ ఏడబ్ల్యూడబ్ల్యూ / ఏడబ్ల్యూసీ ఉపయోగకర్తా ద్వారా ఆసానీ సే దోబారా నిర్ధారిత కియా జా సకతా హై। ఆపకో భూల గఏ ఏమపీఆఈఏన పర క్లిక కరనా హోగా, ఔర అపనా పంజీకృత మోబాఇల నంబర దర్జ కరనా హోగా। ఆపకో అపనే పంజీకృత మోబాఇల నంబర పర ఓటీపీ ప్రాప్త హోగా ఔర ఆప అపనే ఏమపీఆఈఏన కో ఆసానీ సే దోబారా నిర్ధారిత కర సకతే హైం।
# పోషణ ట్రైకర ఐప కితనీ భాషాఓం మేం ఉపలబ్ధ హై?
# పోషణ ట్రైకర ఐప 22 అలగ-అలగ భాషాఓం మేం ఉపలబ్ధ హై।
# ఉపలబ్ధ విభిన్న భాషాఏఁ హైం:
# అంగ్రేజీ
# హిందీ
# గుజరాతీ
# పంజాబీ
# మరాఠీ
# బంగలా
# కన్నడ఼
# తమిల
# తేలుగు
# మలాయలమ
# ఓడియా
# అసమియా
# Nepali
# Dogri
# Konkani
# Sindhi
# Bodo
# Maithili
# Manipuri
# Santhali
# Urdu
# Kashmiri
# ఫ౉ర్మ భరతే సమయ ఏడబ్ల్యూడబ్ల్యూ యా ఏడబ్ల్యూసీ కితనీ భాషాఓం మేం డేటా దర్జ కర సకతీ హై?
# ఏడబ్ల్యూడబ్ల్యూ అంగ్రేజీ భాషా మేం హీ ఫ౉ర్మ భర సకతా హై।
# పోషణ ట్రైకర ఐప మేం కితనే విభిన్న రూప హైం?
# లాభార్థియోం కే లిఏ 7 విభిన్న ప్రకార కే ఫ౉ర్మ హైం। ఇసమేం శామిల హైం:
# స్తనపాన కరానే వాలీ మాం
# గర్భవతీ మహిలాఏం
# బచ్చా 0-6 మహీనే
# బచ్చా 6 మహీనే సే 3 సాల తక
# బాల 3 సాల సే 6 సాల
# కిశోర లడ఼కియాం (11 సాల -19 సాల)
# ఏడబ్ల్యూసీ ఫ౉ర్మ మేం కౌన సీ జానకారీ జోడ఼ీ జానీ చాహిఏ?
# ఏడబ్ల్యూడబ్ల్యూ ఏక విశేష ఆంగనవాడ఼ీ కేంద్ర మేం మౌజూద బునియాదీ ఢాంచే సే సంబంధిత వివరణ దర్జ కరనే కే లిఏ ఆవశ్యక హైం। ఇసమేం సంరచనా, బునియాదీ సువిధాఏం, సుఖ-సువిధాఏఁ, స్వచ్ఛతా, పేయజల ఆది శామిల హైం।
# అగర వే అపనే మోబాఇల నంబరోం కే మాధ్యమ సే పంజీకరణ కరనే మేం అసమర్థ హైం, తో ఏడబ్ల్యూడబ్ల్యూ ఐప పర సాఇన అప కైసే కర సకతా హై?
# యది ఏడబ్ల్యూడబ్ల్యూ ఖుద కో పంజీకృత కరనే మేం అసఫల హై తో 2 సంభావనాఏం హో సకతీ హైం:
# రాజ్యోం ద్వారా ఏమఓడబ్ల్యూసీడీ కో ఉపలబ్ధ కరాఏ గఏ డేటా మేం ఉనకా మోబాఇల నంబర మౌజూద నహీం హై।
# వే ప్రణాలీ మేం నఏ జోడ఼ే గఏ హైం ఔర ఉనకా మోబాఇల నంబర అభీ తక రాజ్య సేల ద్వారా ఏమఓడబ్ల్యూసీడీ కో ప్రదాన నహీం కియా గయా హై।
# ఉపరోక్త దోనోం మామలోం మేం రాజ్య నోడల అధికారియోం కో ఏడబ్ల్యూడబ్ల్యూ మేం సే కిసీ కో జోడ఼నే / సంపాదిత / సక్రియ / నిష్క్రియ కరనే కా అధికార హై।
# పోషణ ట్రైకర డైశబోర్డ తక కోఈ కైసే పహుంచ సకతా హై?
# పోషణ ట్రైకర డైశబోర్డ కో డైశబోర్డ పర సాఇన కరకే పహుఁచా జా సకతా హై। డైశబోర్డ కో లింక పర క్లిక కరకే ఏక్సేస కియా జా సకతా హై https://poshantracker.in/admin కేవల నేశనల మేం నామిత నోడల స్తర కే అధికారీ డైశబోర్డ తక పహుఁచనే కే లిఏ రాజ్య, జిలా, పరియోజనా ఔర సేక్టర స్తర కో ఏక అద్వితీయ ప్రమాణికతా ప్రదాన కీ జాతీ హై।
# కోఈ ఏడబ్ల్యూడబ్ల్యూ / ఏడబ్ల్యూసీ కైసే జోడ఼ సకతా హై?
# ఏడబ్ల్యూడబ్ల్యూ / ఏడబ్ల్యూసీ కో కేవల నోడల స్తర కే అధికారీ ద్వారా జోడ఼ా జా సకతా హై। పదానుక్రమ మేం ఊపర కీ ఓర కోఈ భీ। రాష్ట్రీయ స్తర కే ఉపయోగకర్తా కే రూప మేం రాజ్య, జిలా, పరియోజనా ఔర క్షేత్ర స్తర ఉపయోగకర్తా బనా సకతే హైం। రాజ్య స్తర కా ఉపయోగకర్తా జిలా, పరియోజనా ఔర క్షేత్ర స్తర కా ఉపయోగకర్తా బనా సకతా హై, జిలా స్తర కా ఉపయోగకర్తా పరియోజనా ఔర క్షేత్ర స్తర కా ఉపయోగకర్తా బనా సకతా హై, పరియోజనా స్తర కా ఉపయోగకర్తా క్షేత్ర కా ఉపయోగకర్తా బనా సకతా హై।
# పోషణ ట్రైకర డైశబోర్డ పర కితనే విభిన్న ప్రకార కే అభిలేఖ ఉత్పన్న కీ జా సకతీ హైం?
# ఐసీ విభిన్న రిపోర్టేం హైం జో
# సే ఉత్పన్న హో సకతీ హైం సామాన్య రిపోర్ట:
# ఐప డాఉనలోడ కీ సంఖ్యా
# పంజీకృత ఆంగనవాడ఼ీ కేంద్రోం కీ కుల సంఖ్యా
# పంజీకృత లాభార్థియోం కీ కుల సంఖ్యా (రాష్ట్రీయ / రాజ్య / జిలా / బ్ల౉క వార)
# పంజీకృత గర్భవతీ మహిలాఓం కీ కుల సంఖ్యా (రాష్ట్రీయ / రాజ్య / జిలా / బ్ల౉కవార)
# పంజీకృత మాతాఓం కీ కుల సంఖ్యా (రాష్ట్రీయ / రాజ్య / జిలా / బ్ల౉క వార)
# పంజీకృత బచ్చోం కీ కుల సంఖ్యా (0-6 మహీనే) పంజీకృత (రాష్ట్రీయ / రాజ్య / జిలా / బ్ల౉కవార)
# పంజీకృత బచ్చోం కీ కుల సంఖ్యా (6 మహీనే) జిలా / బ్ల౉క వార)
# మాతృ ఏవం శిశు పోషణ:
# 21 దినోం మేం కితనే లాభార్థియోం కో THR మిలా
# కితనే బచ్చే స్తనపాన కరతే హైం ప్రసవ కే బాద పహలే ఘంటే మేం విశేష రూప సే
# కితనీ స్తనపాన కరానే వాలీ మాతాఓం కో ఏచసీఏమ దియా జాతా హై
# కితనే బచ్చే విశేష రూప సే ప్రాథమికీ మేం స్తనపాన కరతే హైం ప్రసవ కే బాద ఘంటే
# 3-6 వర్ష కీ ఆయు కే బచ్చోం మేం కైల్శియమ కా ఔసత స్తర
# 3-6 వర్ష కీ ఆయు కే బచ్చోం మేం లోహే కా ఔసత స్తర
# టీకాకరణ కీ కుల సంఖ్యా ప్రతి మాహ ప్రశాసిత (బ్ల౉క, జిలా, రాజ్య, రాష్ట్రీయ స్తర)
# ప్రతి మాహ ప్రశాసిత విశిష్ట రిపోర్ట (బీసీజీ / ఓపీవీ / హేపేటాఇటిస బీ / రోటావాయరస / పోలియో / న్యూమోకోకల / పేంటాలేంటల)
# ఏడబ్ల్యూసీ అవసంరచనా:
# ఏడబ్ల్యూసీ కీ సంఖ్యా (బ్ల౉క, జిలా, రాజ్య, రాష్ట్రీయ స్తర)
# బాలవికాస కీ కుల సంఖ్యా (బ్ల౉క జిలా, రాజ్య, రాష్ట్రీయ స్తర)
# స్వచ్ఛ పేయజల కే సాథ ఏడబ్ల్యూసీ (బ్ల౉క, జిలా, రాజ్య, రాష్ట్రీయ స్తర) కీ కుల సంఖ్యా
# కార్య భార పైమానే కే సాథ ఏడబ్ల్యూసీ (బ్ల౉క, జిలా, రాజ్య, రాష్ట్రీయ స్తర) కీ కుల సంఖ్యా
# బిజలీ కే సాథ ఏడబ్ల్యూసీ (బ్ల౉క, జిలా, రాజ్య, రాష్ట్రీయ స్తర) కీ కుల సంఖ్యా
# సరకార కీ స్వామిత్వ వాలీ ఏడబ్ల్యూసీ కీ కుల సంఖ్యా
# నిజీ తౌర పర హోనే వాలే ఏడబ్ల్యూసీ కీ కుల సంఖ్యా స్వామిత్వ
# పోశన ట్రైకర సమూహ సే కైసే సంపర్క కరేం?
# పోషణ ట్రైకర సమూహ సే support-poshantrackr@gov.in పర ఈమేల భేజకర సంపర్క కియా జా సకతా హై। ఆపకే సహయోగ ఔర సమర్థన కే లిఏ హమ ప్రతిదిన శామ 4:15 బజే సే శామ 5:15 బజే తక వీడియో క౉న్ఫ్రేంస పర భీ ఉపలబ్ధ హైం।

# %%
from indicnlp.transliterate.unicode_transliterate import UnicodeIndicTransliterator
input_text="""पोषण अभियान क्या है?
पोषण अभियान क्या है?
पोषण अभियान, एक लक्षित दृष्टिकोण और अभिसरण द्वारा बच्चों, किशोरों, गर्भवती महिलाओं और स्तनपान कराने वाली माताओं के लिए पोषण संबंधी परिणामों में सुधार करने के लिए भारत का प्रमुख कार्यक्रम है।
पोषण ट्रैकर लॉन्च करने का उद्देश्य क्या है?
पोषण ट्रैकर एप्लिकेशन का उद्देश्य आंगनवाड़ी केंद्र (एडब्ल्यूसी), आंगनवाड़ी कर्मचारी (एडब्ल्यूडब्ल्यू) की सेवा प्रदान करने वाली गतिविधियों और गर्भवती महिलाओं, स्तनपान कराने वाली माताओं और बच्चों के लिए पूर्ण लाभार्थी प्रबंधन की गतिविधियों का 360 डिग्री दृश्य प्रदान करना है। प्रस्तावित प्रणाली को सभी एडब्ल्यूसी, एडब्ल्यू डब्ल्यू और लाभार्थियों को परिभाषित संकेतक पर वास्तविक समय की निगरानी और समझना सक्षम करना चाहिए।
पोषण ट्रैकर ऐप को कैसे डाउनलोड किया जा सकता है?
पोषण ट्रैकर ऐप गूगल प्ले स्टोर https://play.google.com/store/apps/details?id=com.poshantracker पर उपलब्ध है।
क्या ऐप्पल आई स्टोर पर भी पोषण ट्रैक ऐप उपलब्ध है?
कोई पोषण ट्रैकर केवल एंड्रॉइड संस्करण के लिए उपलब्ध नहीं है।
मोबाइल में पोषण ट्रैकर ऐप इंस्टॉल करने के लिए न्यूनतम आवश्यकता क्या है?
पोषण ट्रैकर ऐप केवल एंड्रॉइड फोन में एंड्रॉइड संस्करण 6.0 और इसके बाद के संस्करण में स्थापित किया जा सकता है।
क्या ऐप को इंटरनेट के बिना अभिगम किया जा सकता है?
कोई भी ऐप वैध इंटरनेट कनेक्शन के बिना काम नहीं करती है।
पोषण ट्रैकर ऐप के टारगेट यूज़रबेस कौन हैं?
पोषण ट्रैकर ऐप आंगनवाड़ी कार्यकर्ताओं के लिए है जो आंगनवाड़ी केंद्रों के लाभार्थियों के डेटा को प्रपत्रों में दर्ज करता है। यह आम जनता के लिए बिल्कुल भी विकसित नहीं है।
पोषण ट्रैकर ऐप में कैसे लॉगिन करें?
एडब्ल्यूडब्ल्यू से अनुरोध है कि लॉगिन स्क्रीन में अपने मोबाइल नंबर दर्ज करें। आपके पंजीकृत मोबाइल नंबर पर एक ओटीपी भेजा जाएगा जिसकी आपको आवश्यकता है, अपना एमपीआईएन स्थापित करें।
एमपीआईएन क्या है?
जो आंगनवाड़ी कार्यकर्ता द्वारा पोषण ट्रैकर ऐप पर पंजीकरण करते समय निर्धारित किया जाता है।
एमपीआईएन कैसे निर्धारित करें?
एमपीआईएन को संबंधित आंगनवाड़ी कार्यकर्ता द्वारा अपने मोबाइल नंबर पर ओटीपी के लिए अनुरोध किया जा सकता है। यदि मोबाइल नंबर पहले से ही डेटाबेस में मौजूद है, तो संबंधित आंगनवाड़ी व्यक्ति को पंजीकृत मोबाइल नंबर पर 4 अंकों का ओटीपी प्राप्त होगा। ओटीपी दर्ज करने के बाद, एडब्ल्यूडब्ल्यू आसानी से अनुकूलित एमपीआईएन निर्धारित कर सकता है।
एमपीआईएन कब और कैसे इस्तेमाल करें?
पोषण ट्रैकर ऐप में लॉगिन करते समय, एडब्ल्यूडब्ल्यू को उनके द्वारा निर्धारित एमपीआई में प्रवेश करना होता है। यह एमपीआईएन पोषण ट्रैकर ऐप चलाने और लाभार्थियों के फॉर्म में जानकारी दर्ज करने के लिए एक पासकोड के रूप में कार्य करेगा।
एमपीआईएन कैसे दोबारा निर्धारित करें?
एमपीआईएन को किसी भी एडब्ल्यूडब्ल्यू / एडब्ल्यूसी उपयोगकर्ता द्वारा आसानी से दोबारा निर्धारित किया जा सकता है। आपको भूल गए एमपीआईएन पर क्लिक करना होगा, और अपना पंजीकृत मोबाइल नंबर दर्ज करना होगा। आपको अपने पंजीकृत मोबाइल नंबर पर ओटीपी प्राप्त होगा और आप अपने एमपीआईएन को आसानी से दोबारा निर्धारित कर सकते हैं।
पोषण ट्रैकर ऐप कितनी भाषाओं में उपलब्ध है?
पोषण ट्रैकर ऐप 22 अलग-अलग भाषाओं में उपलब्ध है।
उपलब्ध विभिन्न भाषाएँ हैं:
अंग्रेजी
हिंदी
गुजराती
पंजाबी
मराठी
बंगला
कन्नड़
तमिल
तेलुगु
मलायलम
ओडिया
असमिया
Nepali
Dogri
Konkani
Sindhi
Bodo
Maithili
Manipuri
Santhali
Urdu
Kashmiri
फॉर्म भरते समय एडब्ल्यूडब्ल्यू या एडब्ल्यूसी कितनी भाषाओं में डेटा दर्ज कर सकती है?
एडब्ल्यूडब्ल्यू अंग्रेजी भाषा में ही फॉर्म भर सकता है।
पोषण ट्रैकर ऐप में कितने विभिन्न रूप हैं?
लाभार्थियों के लिए 7 विभिन्न प्रकार के फॉर्म हैं। इसमें शामिल हैं:
स्तनपान कराने वाली मां
गर्भवती महिलाएं
बच्चा 0-6 महीने
बच्चा 6 महीने से 3 साल तक
बाल 3 साल से 6 साल
किशोर लड़कियां (11 साल -19 साल) 
एडब्ल्यूसी फॉर्म में कौन सी जानकारी जोड़ी जानी चाहिए?
एडब्ल्यूडब्ल्यू एक विशेष आंगनवाड़ी केंद्र में मौजूद बुनियादी ढांचे से संबंधित विवरण दर्ज करने के लिए आवश्यक हैं। इसमें संरचना, बुनियादी सुविधाएं, सुख-सुविधाएँ, स्वच्छता, पेयजल आदि शामिल हैं।
अगर वे अपने मोबाइल नंबरों के माध्यम से पंजीकरण करने में असमर्थ हैं, तो एडब्ल्यूडब्ल्यू ऐप पर साइन अप कैसे कर सकता है?
यदि एडब्ल्यूडब्ल्यू खुद को पंजीकृत करने में असफल है तो 2 संभावनाएं हो सकती हैं:
राज्यों द्वारा एमओडब्ल्यूसीडी को उपलब्ध कराए गए डेटा में उनका मोबाइल नंबर मौजूद नहीं है।
वे प्रणाली में नए जोड़े गए हैं और उनका मोबाइल नंबर अभी तक राज्य सेल द्वारा एमओडब्ल्यूसीडी को प्रदान नहीं किया गया है।
उपरोक्त दोनों मामलों में राज्य नोडल अधिकारियों को एडब्ल्यूडब्ल्यू में से किसी को जोड़ने / संपादित / सक्रिय / निष्क्रिय करने का अधिकार है।
पोषण ट्रैकर डैशबोर्ड तक कोई कैसे पहुंच सकता है?
पोषण ट्रैकर डैशबोर्ड को डैशबोर्ड पर साइन करके पहुँचा जा सकता है। डैशबोर्ड को लिंक पर क्लिक करके एक्सेस किया जा सकता है https://poshantracker.in/admin केवल नेशनल में नामित नोडल स्तर के अधिकारी डैशबोर्ड तक पहुँचने के लिए राज्य, जिला, परियोजना और सेक्टर स्तर को एक अद्वितीय प्रमाणिकता प्रदान की जाती है।
कोई एडब्ल्यूडब्ल्यू / एडब्ल्यूसी कैसे जोड़ सकता है?
एडब्ल्यूडब्ल्यू / एडब्ल्यूसी को केवल नोडल स्तर के अधिकारी द्वारा जोड़ा जा सकता है। पदानुक्रम में ऊपर की ओर कोई भी। राष्ट्रीय स्तर के उपयोगकर्ता के रूप में राज्य, जिला, परियोजना और क्षेत्र स्तर उपयोगकर्ता बना सकते हैं। राज्य स्तर का उपयोगकर्ता जिला, परियोजना और क्षेत्र स्तर का उपयोगकर्ता बना सकता है, जिला स्तर का उपयोगकर्ता परियोजना और क्षेत्र स्तर का उपयोगकर्ता बना सकता है, परियोजना स्तर का उपयोगकर्ता क्षेत्र का उपयोगकर्ता बना सकता है।
पोषण ट्रैकर डैशबोर्ड पर कितने विभिन्न प्रकार के अभिलेख उत्पन्न की जा सकती हैं?
ऐसी विभिन्न रिपोर्टें हैं जो
से उत्पन्न हो सकती हैं सामान्य रिपोर्ट:
ऐप डाउनलोड की संख्या
पंजीकृत आंगनवाड़ी केंद्रों की कुल संख्या
पंजीकृत लाभार्थियों की कुल संख्या (राष्ट्रीय / राज्य / जिला / ब्लॉक वार)
पंजीकृत गर्भवती महिलाओं की कुल संख्या (राष्ट्रीय / राज्य / जिला / ब्लॉकवार)
पंजीकृत माताओं की कुल संख्या (राष्ट्रीय / राज्य / जिला / ब्लॉक वार)
पंजीकृत बच्चों की कुल संख्या (0-6 महीने) पंजीकृत (राष्ट्रीय / राज्य / जिला / ब्लॉकवार)
पंजीकृत बच्चों की कुल संख्या (6 महीने) जिला / ब्लॉक वार)
मातृ एवं शिशु पोषण:
21 दिनों में कितने लाभार्थियों को THR मिला
कितने बच्चे स्तनपान करते हैं प्रसव के बाद पहले घंटे में विशेष रूप से
कितनी स्तनपान कराने वाली माताओं को एचसीएम दिया जाता है
कितने बच्चे विशेष रूप से प्राथमिकी में स्तनपान करते हैं प्रसव के बाद घंटे
3-6 वर्ष की आयु के बच्चों में कैल्शियम का औसत स्तर
3-6 वर्ष की आयु के बच्चों में लोहे का औसत स्तर
टीकाकरण की कुल संख्या प्रति माह प्रशासित (ब्लॉक, जिला, राज्य, राष्ट्रीय स्तर)
प्रति माह प्रशासित विशिष्ट रिपोर्ट (बीसीजी / ओपीवी / हेपेटाइटिस बी / रोटावायरस / पोलियो / न्यूमोकोकल / पेंटालेंटल)
एडब्ल्यूसी अवसंरचना:
एडब्ल्यूसी की संख्या (ब्लॉक, जिला, राज्य, राष्ट्रीय स्तर)
बालविकास की कुल संख्या (ब्लॉक जिला, राज्य, राष्ट्रीय स्तर)
स्वच्छ पेयजल के साथ एडब्ल्यूसी (ब्लॉक, जिला, राज्य, राष्ट्रीय स्तर) की कुल संख्या
कार्य भार पैमाने के साथ एडब्ल्यूसी (ब्लॉक, जिला, राज्य, राष्ट्रीय स्तर) की कुल संख्या
बिजली के साथ एडब्ल्यूसी (ब्लॉक, जिला, राज्य, राष्ट्रीय स्तर) की कुल संख्या
सरकार की स्वामित्व वाली एडब्ल्यूसी की कुल संख्या
निजी तौर पर होने वाले एडब्ल्यूसी की कुल संख्या स्वामित्व
पोशन ट्रैकर समूह से कैसे संपर्क करें?
पोषण ट्रैकर समूह से support-poshantrackr@gov.in पर ईमेल भेजकर संपर्क किया जा सकता है। आपके सहयोग और समर्थन के लिए हम प्रतिदिन शाम 4:15 बजे से शाम 5:15 बजे तक वीडियो कॉन्फ्रेंस पर भी उपलब्ध हैं।"""
# input_text='രാജസ്ഥാന'
# input_text='රාජස්ථාන'
print(UnicodeIndicTransliterator.transliterate(input_text,"hi","ta"))
# Out:
# போஷண அபியாந க்யா ஹை?
# போஷண அபியாந க்யா ஹை?
# போஷண அபியாந, ஏக லக்ஷித த௃ஷ்டிகோண ஔர அபிஸரண த்வாரா பச்சோஂ, கிஷோரோஂ, கர்பவதீ மஹிலாஓஂ ஔர ஸ்தநபாந கராநே வாலீ மாதாஓஂ கே லிஏ போஷண ஸஂபஂதீ பரிணாமோஂ மேஂ ஸுதார கரநே கே லிஏ பாரத கா ப்ரமுக கார்யக்ரம ஹை।
# போஷண ட்ரைகர ல௉ந்ச கரநே கா உத்தேஷ்ய க்யா ஹை?
# போஷண ட்ரைகர ஏப்லிகேஷந கா உத்தேஷ்ய ஆஂகநவாட஼ீ கேஂத்ர (ஏடப்ல்யூஸீ), ஆஂகநவாட஼ீ கர்மசாரீ (ஏடப்ல்யூடப்ல்யூ) கீ ஸேவா ப்ரதாந கரநே வாலீ கதிவிதியோஂ ஔர கர்பவதீ மஹிலாஓஂ, ஸ்தநபாந கராநே வாலீ மாதாஓஂ ஔர பச்சோஂ கே லிஏ பூர்ண லாபார்தீ ப்ரபஂதந கீ கதிவிதியோஂ கா 360 டிக்ரீ த௃ஷ்ய ப்ரதாந கரநா ஹை। ப்ரஸ்தாவித ப்ரணாலீ கோ ஸபீ ஏடப்ல்யூஸீ, ஏடப்ல்யூ டப்ல்யூ ஔர லாபார்தியோஂ கோ பரிபாஷித ஸஂகேதக பர வாஸ்தவிக ஸமய கீ நிகராநீ ஔர ஸமசநா ஸக்ஷம கரநா சாஹிஏ।
# போஷண ட்ரைகர ஐப கோ கைஸே டாஉநலோட கியா ஜா ஸகதா ஹை?
# போஷண ட்ரைகர ஐப கூகல ப்லே ஸ்டோர https://play.google.com/store/apps/details?id=com.poshantracker பர உபலப்த ஹை।
# க்யா ஐப்பல ஆஈ ஸ்டோர பர பீ போஷண ட்ரைக ஐப உபலப்த ஹை?
# கோஈ போஷண ட்ரைகர கேவல ஏஂட்ர௉இட ஸஂஸ்கரண கே லிஏ உபலப்த நஹீஂ ஹை।
# மோபாஇல மேஂ போஷண ட்ரைகர ஐப இஂஸ்ட௉ல கரநே கே லிஏ ந்யூநதம ஆவஷ்யகதா க்யா ஹை?
# போஷண ட்ரைகர ஐப கேவல ஏஂட்ர௉இட போந மேஂ ஏஂட்ர௉இட ஸஂஸ்கரண 6.0 ஔர இஸகே பாத கே ஸஂஸ்கரண மேஂ ஸ்தாபித கியா ஜா ஸகதா ஹை।
# க்யா ஐப கோ இஂடரநேட கே பிநா அபிகம கியா ஜா ஸகதா ஹை?
# கோஈ பீ ஐப வைத இஂடரநேட கநேக்ஷந கே பிநா காம நஹீஂ கரதீ ஹை।
# போஷண ட்ரைகர ஐப கே டாரகேட யூஜ஼ரபேஸ கௌந ஹைஂ?
# போஷண ட்ரைகர ஐப ஆஂகநவாட஼ீ கார்யகர்தாஓஂ கே லிஏ ஹை ஜோ ஆஂகநவாட஼ீ கேஂத்ரோஂ கே லாபார்தியோஂ கே டேடா கோ ப்ரபத்ரோஂ மேஂ தர்ஜ கரதா ஹை। யஹ ஆம ஜநதா கே லிஏ பில்குல பீ விகஸித நஹீஂ ஹை।
# போஷண ட்ரைகர ஐப மேஂ கைஸே ல௉கிந கரேஂ?
# ஏடப்ல்யூடப்ல்யூ ஸே அநுரோத ஹை கி ல௉கிந ஸ்க்ரீந மேஂ அபநே மோபாஇல நஂபர தர்ஜ கரேஂ। ஆபகே பஂஜீக௃த மோபாஇல நஂபர பர ஏக ஓடீபீ பேஜா ஜாஏகா ஜிஸகீ ஆபகோ ஆவஷ்யகதா ஹை, அபநா ஏமபீஆஈஏந ஸ்தாபித கரேஂ।
# ஏமபீஆஈஏந க்யா ஹை?
# ஜோ ஆஂகநவாட஼ீ கார்யகர்தா த்வாரா போஷண ட்ரைகர ஐப பர பஂஜீகரண கரதே ஸமய நிர்தாரித கியா ஜாதா ஹை।
# ஏமபீஆஈஏந கைஸே நிர்தாரித கரேஂ?
# ஏமபீஆஈஏந கோ ஸஂபஂதித ஆஂகநவாட஼ீ கார்யகர்தா த்வாரா அபநே மோபாஇல நஂபர பர ஓடீபீ கே லிஏ அநுரோத கியா ஜா ஸகதா ஹை। யதி மோபாஇல நஂபர பஹலே ஸே ஹீ டேடாபேஸ மேஂ மௌஜூத ஹை, தோ ஸஂபஂதித ஆஂகநவாட஼ீ வ்யக்தி கோ பஂஜீக௃த மோபாஇல நஂபர பர 4 அஂகோஂ கா ஓடீபீ ப்ராப்த ஹோகா। ஓடீபீ தர்ஜ கரநே கே பாத, ஏடப்ல்யூடப்ல்யூ ஆஸாநீ ஸே அநுகூலித ஏமபீஆஈஏந நிர்தாரித கர ஸகதா ஹை।
# ஏமபீஆஈஏந கப ஔர கைஸே இஸ்தேமால கரேஂ?
# போஷண ட்ரைகர ஐப மேஂ ல௉கிந கரதே ஸமய, ஏடப்ல்யூடப்ல்யூ கோ உநகே த்வாரா நிர்தாரித ஏமபீஆஈ மேஂ ப்ரவேஷ கரநா ஹோதா ஹை। யஹ ஏமபீஆஈஏந போஷண ட்ரைகர ஐப சலாநே ஔர லாபார்தியோஂ கே ப௉ர்ம மேஂ ஜாநகாரீ தர்ஜ கரநே கே லிஏ ஏக பாஸகோட கே ரூப மேஂ கார்ய கரேகா।
# ஏமபீஆஈஏந கைஸே தோபாரா நிர்தாரித கரேஂ?
# ஏமபீஆஈஏந கோ கிஸீ பீ ஏடப்ல்யூடப்ல்யூ / ஏடப்ல்யூஸீ உபயோககர்தா த்வாரா ஆஸாநீ ஸே தோபாரா நிர்தாரித கியா ஜா ஸகதா ஹை। ஆபகோ பூல கஏ ஏமபீஆஈஏந பர க்லிக கரநா ஹோகா, ஔர அபநா பஂஜீக௃த மோபாஇல நஂபர தர்ஜ கரநா ஹோகா। ஆபகோ அபநே பஂஜீக௃த மோபாஇல நஂபர பர ஓடீபீ ப்ராப்த ஹோகா ஔர ஆப அபநே ஏமபீஆஈஏந கோ ஆஸாநீ ஸே தோபாரா நிர்தாரித கர ஸகதே ஹைஂ।
# போஷண ட்ரைகர ஐப கிதநீ பாஷாஓஂ மேஂ உபலப்த ஹை?
# போஷண ட்ரைகர ஐப 22 அலக-அலக பாஷாஓஂ மேஂ உபலப்த ஹை।
# உபலப்த விபிந்ந பாஷாஏ஁ ஹைஂ:
# அஂக்ரேஜீ
# ஹிஂதீ
# குஜராதீ
# பஂஜாபீ
# மராடீ
# பஂகலா
# கந்நட஼
# தமில
# தேலுகு
# மலாயலம
# ஓடியா
# அஸமியா
# Nepali
# Dogri
# Konkani
# Sindhi
# Bodo
# Maithili
# Manipuri
# Santhali
# Urdu
# Kashmiri
# ப௉ர்ம பரதே ஸமய ஏடப்ல்யூடப்ல்யூ யா ஏடப்ல்யூஸீ கிதநீ பாஷாஓஂ மேஂ டேடா தர்ஜ கர ஸகதீ ஹை?
# ஏடப்ல்யூடப்ல்யூ அஂக்ரேஜீ பாஷா மேஂ ஹீ ப௉ர்ம பர ஸகதா ஹை।
# போஷண ட்ரைகர ஐப மேஂ கிதநே விபிந்ந ரூப ஹைஂ?
# லாபார்தியோஂ கே லிஏ 7 விபிந்ந ப்ரகார கே ப௉ர்ம ஹைஂ। இஸமேஂ ஷாமில ஹைஂ:
# ஸ்தநபாந கராநே வாலீ மாஂ
# கர்பவதீ மஹிலாஏஂ
# பச்சா 0-6 மஹீநே
# பச்சா 6 மஹீநே ஸே 3 ஸால தக
# பால 3 ஸால ஸே 6 ஸால
# கிஷோர லட஼கியாஂ (11 ஸால -19 ஸால)
# ஏடப்ல்யூஸீ ப௉ர்ம மேஂ கௌந ஸீ ஜாநகாரீ ஜோட஼ீ ஜாநீ சாஹிஏ?
# ஏடப்ல்யூடப்ல்யூ ஏக விஷேஷ ஆஂகநவாட஼ீ கேஂத்ர மேஂ மௌஜூத புநியாதீ டாஂசே ஸே ஸஂபஂதித விவரண தர்ஜ கரநே கே லிஏ ஆவஷ்யக ஹைஂ। இஸமேஂ ஸஂரசநா, புநியாதீ ஸுவிதாஏஂ, ஸுக-ஸுவிதாஏ஁, ஸ்வச்சதா, பேயஜல ஆதி ஷாமில ஹைஂ।
# அகர வே அபநே மோபாஇல நஂபரோஂ கே மாத்யம ஸே பஂஜீகரண கரநே மேஂ அஸமர்த ஹைஂ, தோ ஏடப்ல்யூடப்ல்யூ ஐப பர ஸாஇந அப கைஸே கர ஸகதா ஹை?
# யதி ஏடப்ல்யூடப்ல்யூ குத கோ பஂஜீக௃த கரநே மேஂ அஸபல ஹை தோ 2 ஸஂபாவநாஏஂ ஹோ ஸகதீ ஹைஂ:
# ராஜ்யோஂ த்வாரா ஏமஓடப்ல்யூஸீடீ கோ உபலப்த கராஏ கஏ டேடா மேஂ உநகா மோபாஇல நஂபர மௌஜூத நஹீஂ ஹை।
# வே ப்ரணாலீ மேஂ நஏ ஜோட஼ே கஏ ஹைஂ ஔர உநகா மோபாஇல நஂபர அபீ தக ராஜ்ய ஸேல த்வாரா ஏமஓடப்ல்யூஸீடீ கோ ப்ரதாந நஹீஂ கியா கயா ஹை।
# உபரோக்த தோநோஂ மாமலோஂ மேஂ ராஜ்ய நோடல அதிகாரியோஂ கோ ஏடப்ல்யூடப்ல்யூ மேஂ ஸே கிஸீ கோ ஜோட஼நே / ஸஂபாதித / ஸக்ரிய / நிஷ்க்ரிய கரநே கா அதிகார ஹை।
# போஷண ட்ரைகர டைஷபோர்ட தக கோஈ கைஸே பஹுஂச ஸகதா ஹை?
# போஷண ட்ரைகர டைஷபோர்ட கோ டைஷபோர்ட பர ஸாஇந கரகே பஹு஁சா ஜா ஸகதா ஹை। டைஷபோர்ட கோ லிஂக பர க்லிக கரகே ஏக்ஸேஸ கியா ஜா ஸகதா ஹை https://poshantracker.in/admin கேவல நேஷநல மேஂ நாமித நோடல ஸ்தர கே அதிகாரீ டைஷபோர்ட தக பஹு஁சநே கே லிஏ ராஜ்ய, ஜிலா, பரியோஜநா ஔர ஸேக்டர ஸ்தர கோ ஏக அத்விதீய ப்ரமாணிகதா ப்ரதாந கீ ஜாதீ ஹை।
# கோஈ ஏடப்ல்யூடப்ல்யூ / ஏடப்ல்யூஸீ கைஸே ஜோட஼ ஸகதா ஹை?
# ஏடப்ல்யூடப்ல்யூ / ஏடப்ல்யூஸீ கோ கேவல நோடல ஸ்தர கே அதிகாரீ த்வாரா ஜோட஼ா ஜா ஸகதா ஹை। பதாநுக்ரம மேஂ ஊபர கீ ஓர கோஈ பீ। ராஷ்ட்ரீய ஸ்தர கே உபயோககர்தா கே ரூப மேஂ ராஜ்ய, ஜிலா, பரியோஜநா ஔர க்ஷேத்ர ஸ்தர உபயோககர்தா பநா ஸகதே ஹைஂ। ராஜ்ய ஸ்தர கா உபயோககர்தா ஜிலா, பரியோஜநா ஔர க்ஷேத்ர ஸ்தர கா உபயோககர்தா பநா ஸகதா ஹை, ஜிலா ஸ்தர கா உபயோககர்தா பரியோஜநா ஔர க்ஷேத்ர ஸ்தர கா உபயோககர்தா பநா ஸகதா ஹை, பரியோஜநா ஸ்தர கா உபயோககர்தா க்ஷேத்ர கா உபயோககர்தா பநா ஸகதா ஹை।
# போஷண ட்ரைகர டைஷபோர்ட பர கிதநே விபிந்ந ப்ரகார கே அபிலேக உத்பந்ந கீ ஜா ஸகதீ ஹைஂ?
# ஐஸீ விபிந்ந ரிபோர்டேஂ ஹைஂ ஜோ
# ஸே உத்பந்ந ஹோ ஸகதீ ஹைஂ ஸாமாந்ய ரிபோர்ட:
# ஐப டாஉநலோட கீ ஸஂக்யா
# பஂஜீக௃த ஆஂகநவாட஼ீ கேஂத்ரோஂ கீ குல ஸஂக்யா
# பஂஜீக௃த லாபார்தியோஂ கீ குல ஸஂக்யா (ராஷ்ட்ரீய / ராஜ்ய / ஜிலா / ப்ல௉க வார)
# பஂஜீக௃த கர்பவதீ மஹிலாஓஂ கீ குல ஸஂக்யா (ராஷ்ட்ரீய / ராஜ்ய / ஜிலா / ப்ல௉கவார)
# பஂஜீக௃த மாதாஓஂ கீ குல ஸஂக்யா (ராஷ்ட்ரீய / ராஜ்ய / ஜிலா / ப்ல௉க வார)
# பஂஜீக௃த பச்சோஂ கீ குல ஸஂக்யா (0-6 மஹீநே) பஂஜீக௃த (ராஷ்ட்ரீய / ராஜ்ய / ஜிலா / ப்ல௉கவார)
# பஂஜீக௃த பச்சோஂ கீ குல ஸஂக்யா (6 மஹீநே) ஜிலா / ப்ல௉க வார)
# மாத௃ ஏவஂ ஷிஷு போஷண:
# 21 திநோஂ மேஂ கிதநே லாபார்தியோஂ கோ THR மிலா
# கிதநே பச்சே ஸ்தநபாந கரதே ஹைஂ ப்ரஸவ கே பாத பஹலே கஂடே மேஂ விஷேஷ ரூப ஸே
# கிதநீ ஸ்தநபாந கராநே வாலீ மாதாஓஂ கோ ஏசஸீஏம தியா ஜாதா ஹை
# கிதநே பச்சே விஷேஷ ரூப ஸே ப்ராதமிகீ மேஂ ஸ்தநபாந கரதே ஹைஂ ப்ரஸவ கே பாத கஂடே
# 3-6 வர்ஷ கீ ஆயு கே பச்சோஂ மேஂ கைல்ஷியம கா ஔஸத ஸ்தர
# 3-6 வர்ஷ கீ ஆயு கே பச்சோஂ மேஂ லோஹே கா ஔஸத ஸ்தர
# டீகாகரண கீ குல ஸஂக்யா ப்ரதி மாஹ ப்ரஷாஸித (ப்ல௉க, ஜிலா, ராஜ்ய, ராஷ்ட்ரீய ஸ்தர)
# ப்ரதி மாஹ ப்ரஷாஸித விஷிஷ்ட ரிபோர்ட (பீஸீஜீ / ஓபீவீ / ஹேபேடாஇடிஸ பீ / ரோடாவாயரஸ / போலியோ / ந்யூமோகோகல / பேஂடாலேஂடல)
# ஏடப்ல்யூஸீ அவஸஂரசநா:
# ஏடப்ல்யூஸீ கீ ஸஂக்யா (ப்ல௉க, ஜிலா, ராஜ்ய, ராஷ்ட்ரீய ஸ்தர)
# பாலவிகாஸ கீ குல ஸஂக்யா (ப்ல௉க ஜிலா, ராஜ்ய, ராஷ்ட்ரீய ஸ்தர)
# ஸ்வச்ச பேயஜல கே ஸாத ஏடப்ல்யூஸீ (ப்ல௉க, ஜிலா, ராஜ்ய, ராஷ்ட்ரீய ஸ்தர) கீ குல ஸஂக்யா
# கார்ய பார பைமாநே கே ஸாத ஏடப்ல்யூஸீ (ப்ல௉க, ஜிலா, ராஜ்ய, ராஷ்ட்ரீய ஸ்தர) கீ குல ஸஂக்யா
# பிஜலீ கே ஸாத ஏடப்ல்யூஸீ (ப்ல௉க, ஜிலா, ராஜ்ய, ராஷ்ட்ரீய ஸ்தர) கீ குல ஸஂக்யா
# ஸரகார கீ ஸ்வாமித்வ வாலீ ஏடப்ல்யூஸீ கீ குல ஸஂக்யா
# நிஜீ தௌர பர ஹோநே வாலே ஏடப்ல்யூஸீ கீ குல ஸஂக்யா ஸ்வாமித்வ
# போஷந ட்ரைகர ஸமூஹ ஸே கைஸே ஸஂபர்க கரேஂ?
# போஷண ட்ரைகர ஸமூஹ ஸே support-poshantrackr@gov.in பர ஈமேல பேஜகர ஸஂபர்க கியா ஜா ஸகதா ஹை। ஆபகே ஸஹயோக ஔர ஸமர்தந கே லிஏ ஹம ப்ரதிதிந ஷாம 4:15 பஜே ஸே ஷாம 5:15 பஜே தக வீடியோ க௉ந்ப்ரேஂஸ பர பீ உபலப்த ஹைஂ।
